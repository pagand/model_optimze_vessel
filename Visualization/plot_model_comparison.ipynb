# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle
from sklearn.metrics import mean_squared_error

# %%
plot(0)

# %%
fig = plt.figure()
grid = plt.GridSpec(2, 2, wspace=0.3, hspace=0.3)

ax1 = plt.subplot(grid[0, 0])
ax2 = plt.subplot(grid[0, 1:])
ax3 = plt.subplot(grid[1, :1])
ax4 = plt.subplot(grid[1, 1:])

ax1.plot(range(25, 61+25), actual_auto, label='Actual'.format(i=1), color="Green")
ax1.plot(range(25, 61+25), predicted_fc, label='Pred NAR'.format(i=3), linestyle='dashed')
ax1.plot(range(25, 61+25), predicted_autogru, label='Pred AR'.format(i=2), linestyle='dashdot', color="Red")
ax2.plot(range(25, 61+25), actual_auto_sog, label='Actuals'.format(i=1), color="Green")
ax2.plot(range(25, 61+25), predicted_sog, label='AR+GRU'.format(i=3), linestyle='dashed')
ax2.plot(range(25, 61+25), predicted_autogru_sog, label='AR+GRU'.format(i=2), linestyle='dashdot', color="Red")
# ax2.legend(loc='best')
ax3.plot(range(25, 61+25), actual_auto_loc, label='actuals'.format(i=1), color="Green")
ax3.plot(range(25, 61+25), predicted_lat, label='AR+GRU'.format(i=3), linestyle='dashed')
ax3.plot(range(25, 61+25), predicted_autogru_loc, label='AR+GRU'.format(i=2), linestyle='dashdot', color="Red")
# ax3.legend(loc='best')
ax4.plot(range(25, 61+25), actual_auto_loc, label='actuals'.format(i=1), color="Green")
ax4.plot(range(25, 61+25), predicted_long, label='AR+GRU'.format(i=3), linestyle='dashed')
ax4.plot(range(25, 61+25), predicted_autogru_loc, label='AR+GRU'.format(i=2), linestyle='dashdot', color="Red")
# ax4.legend(loc='best')
ax1.legend(loc='best', fontsize=9)
ax1.set_ylabel("FC", fontsize=9)
ax2.set_ylabel("SOG", fontsize=9)
ax3.set_ylabel("LATITUDE", fontsize=9)
ax4.set_ylabel("LONGITUDE", fontsize=9)
ax1.set_xlabel("Time(mins)", fontsize=9)
ax2.set_xlabel("Time(mins)", fontsize=9)
ax3.set_xlabel("Time(mins)", fontsize=9)
ax4.set_xlabel("Time(mins)", fontsize=9)
ax1.tick_params(axis='both', labelsize=9)
ax2.tick_params(axis='both', labelsize=9)
ax3.tick_params(axis='both', labelsize=9)
ax4.tick_params(axis='both', labelsize=9)

# fig.suptitle('Actual vs Predicted, using previous output as input')
plt.savefig("comparison_plot.eps", format='eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
